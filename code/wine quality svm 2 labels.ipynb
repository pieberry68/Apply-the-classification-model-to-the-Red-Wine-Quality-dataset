# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
wineQuality=pd.read_csv("E:\winequality-red.csv")
wineQuality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wineQuality.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
from scipy import stats
z = np.abs(stats.zscore(wineQuality))
wineQuality = wineQuality[(z < 3).all(axis=1)]
wineQuality.shape
# Out:
# (1451, 12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(15, 10))
sns.heatmap(wineQuality.corr(), annot = True, cmap = 'coolwarm')

# %%
import numpy as np
wineQuality["isItGood"] =np.where(wineQuality["quality"] > 5, 1, 0)
#changing it to binary category
wineQuality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
features= ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']
X = wineQuality[features] # Features
y = wineQuality.isItGood # Target variable
print(len(features))
# Out:
# 11

# %%
for i in range(11):
 sns.boxplot(x=y,y=X.iloc[:,i])
 plt.ylabel(features[i])
 plt.show()

# %%
for i in range(11):
    plt.hist(X.iloc[:,i], edgecolor='white')
    plt.title(features[i])
    plt.show()

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=350)

# %%
kernel=['linear','rbf','poly']
for i in kernel:
    model=SVC(kernel=i,C=1.0)
    model.fit(X_train,y_train)
    print('Kernel:',i)
    print('Accuracy:',model.score(X_test,y_test))
# Out:
# Kernel: linear
# Accuracy: 0.8144329896907216
# Kernel: rbf
# Accuracy: 0.8247422680412371
# Kernel: poly
# Accuracy: 0.8213058419243986

# %%
model=SVC()
model.fit(X_train,y_train)
print(" Accuracy on test data ",model.score(X_test,y_test))
print(" Accuracy on train data ",model.score(X_train,y_train))
# Out:
#  Accuracy on test data  0.8247422680412371
#  Accuracy on train data  0.7931034482758621

# %%
for i in range(1,5):
    model=SVC(kernel='poly',degree=i,C=100)
    model.fit(X_train,y_train)
    print(" Accuracy on test data ",model.score(X_test,y_test))
    print(" Accuracy on train data ",model.score(X_train,y_train))
# Out:
#  Accuracy on test data  0.8178694158075601
#  Accuracy on train data  0.7336206896551725
#  Accuracy on test data  0.6288659793814433
#  Accuracy on train data  0.7034482758620689
#  Accuracy on test data  0.7869415807560137
#  Accuracy on train data  0.8551724137931035
#  Accuracy on test data  0.7216494845360825
#  Accuracy on train data  0.928448275862069

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[1,100,1000],'kernel':['linear','rbf','poly'],'degree':[1,2,3]}
grid=GridSearchCV(SVC(),param_grid)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 100, 1000], 'degree': [1, 2, 3],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
print(grid.best_params_)
print(grid.score(X_test,y_test))
# Out:
# {'C': 1, 'degree': 1, 'kernel': 'rbf'}
# 0.8247422680412371
